# %% [markdown]
# ## HƯỚNG DẪN TRAIN SIÊU TỐC DMS BẰNG GPU MIỄN PHÍ TRÊN COLAB
# 1. Hãy chắc chắn bạn đã kích hoạt **T4 GPU** ở mục `Runtime` -> `Change runtime type`.
# 2. Đảm bảo file nén `DMS_Project_Full.zip` đã được upload thẳng vào thư mục ngoài cùng ổ cứng Google Drive của bạn (MyDrive).
# 3. Lần lượt chạy các khối lệnh dưới đây bằng cách bấm nút Play (▶).

# %%
# Khối lẹnh 1: Kết nối (Móc nối) vào Google Drive của Bạn
from google.colab import drive
drive.mount('/content/drive')

# %%
# Khối lệnh 2: Giải nén toàn bộ thư mục Đồ án Project 1.5GB vào máy ảo siêu tốc
# !cp /content/drive/MyDrive/DMS_Project_Full.zip /content/DMS_Project_Full.zip
# !unzip -q /content/DMS_Project_Full.zip -d /content/DMS_Project
print("✅ Giải nén thành công toàn bộ thư mục D:\DMS_Project của bạn!")

# %%
# Khối lệnh 3: Bắt tay vào Huấn luyên AI (Sức mạnh WingLoss & Adam GPU)
# !cd /content/DMS_Project && python src/train.py

# %%
# Khối lệnh 4: Trả lại tác phẩm Vàng - File Mô hình landmark.pth đã Train xong về Google Drive cá nhân để tải về máy D:\
# !cp /content/DMS_Project/landmark.pth /content/drive/MyDrive/landmark_da_train_xong_bang_GPU.pth
print("🎉 Đã lưu xong bản AI trí tuệ về Drive! Bạn tải về máy đổi tên lại thành landmark.pth đè vào ổ D:\DMS_Project là chạy được!")
